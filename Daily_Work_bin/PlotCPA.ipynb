# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mp

# %%
with open('./V_V_PosAndJijs.npy', 'rb') as f:
    V_V_pos = np.load(f)
    V_V_jijs = np.load(f)
    
with open('./V_Cr_PosToJijs_05_vs_05.npy', 'rb') as f:
    V_Cr_pos = np.load(f)
    V_Cr_jijs = np.load(f)

with open('./V_Mn_PosToJijs_05_vs_05.npy', 'rb') as f:
    V_Mn_pos = np.load(f)
    V_Mn_jijs = np.load(f)
    
with open('./V_Mo_PosToJijs_05_vs_05.npy', 'rb') as f:
    V_Mo_pos = np.load(f)
    V_Mo_jijs = np.load(f)

    
## Plot for Cr --------------
with open('./Cr_V_PosToJijs_05_vs_05.npy', 'rb') as f:
    Cr_V_pos = np.load(f)
    Cr_V_jijs = np.load(f)
    
with open('./Cr_Cr_PosAndJijs.npy', 'rb') as f:
    Cr_Cr_pos = np.load(f)
    Cr_Cr_jijs = np.load(f)
    
with open('./Cr_Mn_PosToJijs_05_vs_05.npy', 'rb') as f:
    Cr_Mn_pos = np.load(f)
    Cr_Mn_jijs = np.load(f)
    
with open('./Cr_Mo_PosToJijs_05_vs_05.npy', 'rb') as f:
    Cr_Mo_pos = np.load(f)
    Cr_Mo_jijs = np.load(f)
    
    
## ## Plot for Mn --------------
with open('./Mn_V_PosToJijs_05_vs_05.npy', 'rb') as f:
    Mn_V_pos = np.load(f)
    Mn_V_jijs = np.load(f)
    
with open('./Mn_Cr_PosToJijs_05_vs_05.npy', 'rb') as f:
    Mn_Cr_pos = np.load(f)
    Mn_Cr_jijs = np.load(f)
    
with open('./Mn_Mn_PosAndJijs.npy', 'rb') as f:
    Mn_Mn_pos = np.load(f)
    Mn_Mn_jijs = np.load(f)
    
with open('./Mn_Mo_PosToJijs_05_vs_05.npy', 'rb') as f:
    Mn_Mo_pos = np.load(f)
    Mn_Mo_jijs = np.load(f)

## Plot for MoMo-------------
with open('./Mo_V_PosToJijs_05_vs_05.npy', 'rb') as f:
    Mo_V_pos = np.load(f)
    Mo_V_jijs = np.load(f)
    
with open('./Mo_Mo_PosAndJijs.npy', 'rb') as f:
    Mo_Mo_pos = np.load(f)
    Mo_Mo_jijs = np.load(f)
with open('./Mo_Cr_PosToJijs_05_vs_05.npy', 'rb') as f:
    Mo_Mn_pos = np.load(f)
    Mo_Mn_jijs = np.load(f)
    
with open('./Mo_Mn_PosToJijs_05_vs_05.npy', 'rb') as f:
    Mo_Cr_pos = np.load(f)
    Mo_Cr_jijs = np.load(f)

# %%
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 17}
plt.rc('font',**font)

legnd_prop = {'weight' : 'bold'}

# %%
## This is the original plot and the next part is
## Just copy of this part
#mp.rcParams['text.usetex'] = True
#plt.rcParams['xtick.bottom'] = plt.rcParams['xtick.labelbottom'] = False
#plt.rcParams['xtick.top'] = plt.rcParams['xtick.labeltop'] = True
#plt.rcParams['axes.titlepad'] = 0#12*2
#plt.rcParams['axes.labelpad'] = 0#12*2


plt.figure(figsize=(30,25))
legend_fontsize = 'small'

mask_limit = 12
xlim = (4,15)
ylim_J = (-30,30)
ylim_abs_D = (-0.1, 2)
ylim_ratio = (0,25)

#  Plot  +++++++++++++++++++++ V vs V ++++++++++++++++++++++++++++++++++

plt.subplot(4,3,1)
#plt.title('V-(V,Cr,Mn,Mo) Exchange interaction vs. distance', fontsize='x-large')

#r0 = np.sqrt(np.sum(pos0**2, axis=1))
#plt.plot(r0, jijs0[:,5], 'kd', ms=15, label='smaller k-mesh')

col = 'r'
r = np.sqrt(np.sum(V_V_pos**2, axis=1))
plt.plot(r, V_V_jijs[:,5], ':', color='r')
plt.plot(r[V_V_jijs[:,1]==10], V_V_jijs[V_V_jijs[:,1]==10][:,5], '*', ms=10, alpha=0.5, label='$V_{Bi1}-V_{Bi1}$', color=col)
plt.plot(r[V_V_jijs[:,1]==12], V_V_jijs[V_V_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$V_{Bi1}-V_{Bi2}$', color=col)

col ='g'

r = np.sqrt(np.sum(V_Cr_pos**2, axis=1))
plt.plot(r, V_Cr_jijs[:,5], ':', color='g')
#plt.plot(r[V_Cr_jijs[:,1]==10], V_Cr_jijs[V_Cr_jijs[:,1]==10][:,5], '*', ms=10, alpha=0.5, label='$V_{Bi1}-V_{Bi1}$', color=col )
plt.plot(r[V_Cr_jijs[:,1]==12], V_Cr_jijs[V_Cr_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$V_{Bi1}-Cr_{Bi2}$', color=col)

col = 'b'
r = np.sqrt(np.sum(V_Mn_pos**2, axis=1))
plt.plot(r, V_Mn_jijs[:,5], ':', color='b')
#plt.plot(r[V_Mn_jijs[:,1]==10], V_Mn_jijs[V_Mn_jijs[:,1]==10][:,5], '*', ms=10, alpha=0.5, label='$V_{Bi1}-V_{Bi1}$', color=col )
plt.plot(r[V_Mn_jijs[:,1]==12], V_Mn_jijs[V_Mn_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$V_{Bi1}-Mn_{Bi2}$', color=col)

col = 'c'
r = np.sqrt(np.sum(V_Mo_pos**2, axis=1))
plt.plot(r, V_Mo_jijs[:,5], ':', color='c')
#plt.plot(r[V_Mo_jijs[:,1]==10], V_Mo_jijs[V_Mo_jijs[:,1]==10][:,5], '*', ms=10, alpha=0.5, label='$V_{Bi1}-V_{Bi1}$', color=col )
plt.plot(r[V_Mo_jijs[:,1]==12], V_Mo_jijs[V_Mo_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$V_{Bi1}-Mo_{Bi2}$', color=col)

plt.ylabel('$J_{ij}$ (meV)', fontsize='x-large')
plt.axhline(0, ls='--', color='grey')
plt.xlabel('$R_{ij}$ ($\AA$)', fontsize='x-large')
plt.xlim(xlim)
plt.ylim(ylim_J)

plt.legend(fontsize=legend_fontsize, loc=1, prop = legnd_prop)

plt.subplot(4,3,2)
#plt.title('DMI vs. distance', fontsize='x-large')

col = 'r'
d = np.sqrt(np.sum(V_V_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='r')
plt.plot(r[V_V_jijs[:,1]==10], d[V_V_jijs[:,1]==10], '*', ms=10, alpha=0.5, label='$V_{Bi1}-V_{Bi1}$', color=col)
plt.plot(r[V_V_jijs[:,1]==12], d[V_V_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$V_{Bi1}-V_{Bi2}$', color=col)

col ='g'
d = np.sqrt(np.sum(V_Cr_jijs[:,6:9]**2, axis=1))
plt.plot(r, d, ':', color='g')
#plt.plot(r[V_Cr_jijs[:,1]==10], d[V_Cr_jijs[:,1]==10], '*', ms=10, alpha=0.5, label='$V_{Bi1}-V_{Bi1}$', color=col)
plt.plot(r[V_Cr_jijs[:,1]==12], d[V_Cr_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$V_{Bi1}-Cr_{Bi2}$', color=col)

col = 'b'
d = np.sqrt(np.sum(V_Mn_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='b')
#plt.plot(r[V_Mn_jijs[:,1]==10], d[V_Mn_jijs[:,1]==10], '*', ms=10, alpha=0.5, label='$V_{Bi1}-V_{Bi1}$', color=col)
plt.plot(r[V_Mn_jijs[:,1]==12], d[V_Mn_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$V_{Bi1}-Mn_{Bi2}$', color=col)

col = 'c'
d = np.sqrt(np.sum(V_Mo_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='c')
#plt.plot(r[V_Mo_jijs[:,1]==10], d[V_Mo_jijs[:,1]==10], '*', ms=10, alpha=0.5, label='$V_{Bi1}-V_{Bi1}$', color=col )
plt.plot(r[V_Mo_jijs[:,1]==12], d[V_Mo_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$V_{Bi1}-Mo_{Bi2}$', color=col)

plt.ylabel('$|\mathbf{D}_{ij}|$ (meV)', fontsize='x-large')
plt.xlabel('$R_{ij}$ ($\AA$)', fontsize='x-large')
plt.ylim(ylim_abs_D)
plt.xlim(xlim)
plt.axhline(0.0, ls='--', color='gray', alpha=0.4)
plt.legend(fontsize=legend_fontsize, loc=1, prop = legnd_prop)

plt.subplot(4,3,3)
#plt.title('D/J', fontsize='x-large')
mask = np.where(r<=mask_limit)

col = 'r'
rr, dd, jj = r[mask], d[mask], V_V_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color=col)
plt.plot(rr[jj[:,1]==10], abs(dd/jj[:,5])[jj[:,1]==10], '*', ms=10, color=col, label='$V_{Bi1}-V_{Bi1}$')
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$V_{Bi1}-V_{Bi2}$')

col ='g'
rr, dd, jj = r[mask], d[mask], V_Cr_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color='g')
#plt.plot(rr[jj[:,1]==10], abs(dd/jj[:,5])[jj[:,1]==10], '*', ms=10, color=col, label='$V_{Bi1}-V_{Bi1}$')
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$V_{Bi1}-Cr_{Bi2}$')

col = 'b'
rr, dd, jj = r[mask], d[mask], V_Mn_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color=col)
#plt.plot(rr[jj[:,1]==10], abs(dd/jj[:,5])[jj[:,1]==10], '*', ms=10, color=col, label='$V_{Bi1}-Mn_{Bi1}$')
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$V_{Bi1}-Mn_{Bi2}$')

col = 'c'
rr, dd, jj = r[mask], d[mask], V_Mo_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color=col)
#plt.plot(rr[jj[:,1]==10], abs(dd/jj[:,5])[jj[:,1]==10], '*', ms=10, color=col, label='$V_{Bi1}-Mo_{Bi1}$')
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$V_{Bi1}-Mo_{Bi2}$')


plt.ylabel('$|\mathbf{D}_{ij}|J_{ij}$', fontsize='x-large')
plt.xlabel('$R_{ij}$ ($\AA$)', fontsize='x-large')
plt.ylim(ylim_ratio)
plt.xlim(xlim)

plt.legend(fontsize=legend_fontsize, loc=1, prop = legnd_prop)
plt.twinx()
#plt.plot(r[mask], (V_V_pos[:,2])[mask], 's:', color='grey')
plt.axhline(0, ls=':', color='grey')
plt.ylabel('z distance ($\AA$)')

plt.tight_layout()

## Plot for Cr
#mp.rcParams['text.usetex'] = True

## ++++++++++++++++++++++++++++++ Cr vs Cr +++++++++++++++++++++++++++++++++++

plt.subplot(4,3,4)
#plt.title('Cr-(V,Cr,Mn,Mo) Exchange interaction vs. distance', fontsize='x-large')

#r0 = np.sqrt(np.sum(pos0**2, axis=1))
#plt.plot(r0, jijs0[:,5], 'kd', ms=15, label='smaller k-mesh')

col = 'r'
r = np.sqrt(np.sum(Cr_Cr_pos**2, axis=1))
plt.plot(r, Cr_Cr_jijs[:,5], ':', color='r')
plt.plot(r[Cr_Cr_jijs[:,1]==10], Cr_Cr_jijs[Cr_Cr_jijs[:,1]==10][:,5], '*', ms=10, alpha=0.5, label='$Cr_{Bi1}-Cr_{Bi1}$', color=col)
plt.plot(r[Cr_Cr_jijs[:,1]==12], Cr_Cr_jijs[Cr_Cr_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$Cr_{Bi1}-Cr_{Bi2}$', color=col)

col ='g'
r = np.sqrt(np.sum(Cr_V_pos**2, axis=1))
plt.plot(r, Cr_V_jijs[:,5], ':', color='g')
plt.plot(r[Cr_V_jijs[:,1]==12], Cr_V_jijs[Cr_V_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$Cr_{Bi1}-V_{Bi2}$', color=col)

col = 'b'
r = np.sqrt(np.sum(Cr_Mn_pos**2, axis=1))
plt.plot(r, Cr_Mn_jijs[:,5], ':', color='b')
#plt.plot(r[Cr_Mn_jijs[:,1]==10], Cr_Mn_jijs[Cr_Mn_jijs[:,1]==10][:,5], '*', ms=10, alpha=0.5, label='$Cr_{Bi1}-Mn_{Bi1}$', color='b' )
plt.plot(r[Cr_Mn_jijs[:,1]==12], Cr_Mn_jijs[Cr_Mn_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$Cr_{Bi1}-Mn_{Bi2}$', color=col)

col = 'c'
r = np.sqrt(np.sum(Cr_Mo_pos**2, axis=1))
plt.plot(r, Cr_Mo_jijs[:,5], ':', color='c')
#plt.plot(r[Cr_Mo_jijs[:,1]==10], Cr_Mo_jijs[Cr_Mo_jijs[:,1]==10][:,5], '*', ms=10, alpha=0.5, label='$Cr_{Bi1}-Mo_{Bi1}$', color='c' )
plt.plot(r[Cr_Mo_jijs[:,1]==12], Cr_Mo_jijs[Cr_Mo_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$Cr_{Bi1}-Mo_{Bi2}$', color=col)

plt.ylabel('$J_{ij}$ (meV)', fontsize='x-large')
plt.axhline(0, ls='--', color='grey')
plt.xlabel('$R_{ij}$ ($\AA$)', fontsize='x-large')
plt.xlim(xlim)
plt.ylim(ylim_J)

plt.legend(fontsize=legend_fontsize, loc=1, prop = legnd_prop)


plt.subplot(4,3,5)
#plt.title('DMI vs. distance', fontsize='x-large')

col = 'r'
r = np.sqrt(np.sum(Cr_Cr_pos**2, axis=1))
d = np.sqrt(np.sum(Cr_Cr_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color=col)
plt.plot(r[Cr_Cr_jijs[:,1]==10], d[Cr_Cr_jijs[:,1]==10], '*', ms=10, alpha=0.5, label='$Cr_{Bi1}-Cr_{Bi1}$', color=col)
plt.plot(r[Cr_Cr_jijs[:,1]==12], d[Cr_Cr_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$Cr_{Bi1}-Cr_{Bi2}$', color=col)

col ='g'
r = np.sqrt(np.sum(Cr_V_pos**2, axis=1))
d = np.sqrt(np.sum(Cr_V_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='g')
plt.plot(r[Cr_V_jijs[:,1]==12], d[Cr_V_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$Cr_{Bi1}-V_{Bi2}$', color=col)

col = 'b'
r = np.sqrt(np.sum(Cr_Mn_pos**2, axis=1))
d = np.sqrt(np.sum(Cr_Mn_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='b')
plt.plot(r[Cr_Mn_jijs[:,1]==12], d[Cr_Mn_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$Cr_{Bi1}-Mn_{Bi2}$', color=col)

col = 'c'
r = np.sqrt(np.sum(Cr_Mo_pos**2, axis=1))
d = np.sqrt(np.sum(Cr_Mo_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='c')
plt.plot(r[Cr_Mo_jijs[:,1]==12], d[Cr_Mo_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$Cr_{Bi1}-Mo_{Bi2}$', color=col)

plt.ylabel('$|\mathbf{D}_{ij}|$ (meV)', fontsize='x-large')
plt.xlabel('$R_{ij}$ ($\AA$)', fontsize='x-large')
plt.ylim(ylim_abs_D)
plt.xlim(xlim)
plt.axhline(0.0, ls='--', color='gray', alpha=0.4)
plt.legend(fontsize=legend_fontsize, loc=1, prop = legnd_prop)

plt.subplot(4,3,6)
#plt.title('D/J', fontsize='x-large')
mask = np.where(r<=mask_limit)

col = 'r'
rr, dd, jj = r[mask], d[mask], Cr_Cr_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color=col)
plt.plot(rr[jj[:,1]==10], abs(dd/jj[:,5])[jj[:,1]==10], '*', ms=10, color=col, label='$Cr_{Bi1}-Cr_{Bi1}$')
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$Cr_{Bi1}-Cr_{Bi2}$')

col ='g'
rr, dd, jj = r[mask], d[mask], Cr_V_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color='g')
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$Cr_{Bi1}-V_{Bi2}$')

col = 'b'
rr, dd, jj = r[mask], d[mask], Cr_Mn_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color=col)
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$Cr_{Bi1}-Mn_{Bi2}$')

col = 'c'
rr, dd, jj = r[mask], d[mask], Cr_Mo_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color=col)
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$Cr_{Bi1}-Mo_{Bi2}$')


plt.ylabel('$|\mathbf{D}_{ij}|J_{ij}$', fontsize='x-large')
plt.xlabel('$R_{ij}$ ($\AA$)', fontsize='x-large')
plt.ylim(ylim_ratio)
plt.xlim(xlim)

plt.legend(fontsize=legend_fontsize, loc=1, prop = legnd_prop)
plt.twinx()
#plt.plot(r[mask], (V_V_pos[:,2])[mask], 's:', color='grey')
plt.axhline(0, ls=':', color='grey')
plt.ylabel('z distance ($\AA$)')

plt.tight_layout()

##++++++++++++++++++++++++++++# Mn-(V,Cr,Mn,Mo) #---------------------------------------------------------------
## Plot for Mn
#mp.rcParams['text.usetex'] = True


# plt.subplot(2,1,1)
plt.subplot(4,3,7)
#plt.title('Mn-(V,Cr,Mn,Mo) Exchange interaction vs. distance', fontsize='x-large')

r = np.sqrt(np.sum(Mn_Mn_pos**2, axis=1))
plt.plot(r, Mn_Mn_jijs[:,5], ':', color='r')
plt.plot(r[Mn_Mn_jijs[:,1]==10], Mn_Mn_jijs[Mn_Mn_jijs[:,1]==10][:,5], '*', ms=10, alpha=0.5, label='$Mn_{Bi1}-Mn_{Bi1}$', color='r')
plt.plot(r[Mn_Mn_jijs[:,1]==12], Mn_Mn_jijs[Mn_Mn_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$Mn_{Bi1}-Mn_{Bi2}$', color='r')

r = np.sqrt(np.sum(Mn_Cr_pos**2, axis=1))
plt.plot(r, Mn_Cr_jijs[:,5], ':', color='g')
plt.plot(r[Mn_Cr_jijs[:,1]==12], Mn_Cr_jijs[Mn_Cr_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$Mn_{Bi1}-Cr_{Bi2}$', color='g')

r = np.sqrt(np.sum(Mn_V_pos**2, axis=1))
plt.plot(r, Mn_V_jijs[:,5], ':', color='b')
plt.plot(r[Mn_V_jijs[:,1]==12], Mn_V_jijs[Mn_V_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$Mn_{Bi1}-V_{Bi2}$', color='b')

r = np.sqrt(np.sum(Mn_Mo_pos**2, axis=1))
plt.plot(r, Mn_Mo_jijs[:,5], ':', color='c')
plt.plot(r[Mn_Mo_jijs[:,1]==12], Mn_Mo_jijs[Mn_Mo_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$Mn_{Bi1}-Mo_{Bi2}$', color='c')

plt.ylabel('$J_{ij}$ (meV)', fontsize='x-large')
plt.axhline(0, ls='--', color='grey')
plt.xlabel('$R_{ij}$ ($\AA$)', fontsize='x-large')
plt.xlim(xlim)
plt.ylim(ylim_J)
plt.legend(fontsize=legend_fontsize, loc=1, prop = legnd_prop)

plt.subplot(4,3,8)
#plt.title('DMI vs. distance', fontsize='x-large')

col = 'r'
d = np.sqrt(np.sum(Mn_Mn_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='r')
plt.plot(r[Mn_Mn_jijs[:,1]==10], d[Mn_Mn_jijs[:,1]==10], '*', ms=10, alpha=0.5, label='$Mn_{Bi1}-Mn_{Bi1}$', color=col)
plt.plot(r[Mn_Mn_jijs[:,1]==12], d[Mn_Mn_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$Mn_{Bi1}-Mn_{Bi2}$', color=col)

col ='g'
d = np.sqrt(np.sum(Mn_Cr_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='g')
plt.plot(r[Mn_Cr_jijs[:,1]==12], d[Mn_Cr_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$Mn_{Bi1}-Cr_{Bi2}$', color=col)

col = 'b'
d = np.sqrt(np.sum(Mn_V_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='b')
plt.plot(r[Mn_V_jijs[:,1]==12], d[Mn_V_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$Mn_{Bi1}-V_{Bi2}$', color=col)

col = 'c'
d = np.sqrt(np.sum(Mn_Mo_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='c')
plt.plot(r[Mn_Mo_jijs[:,1]==12], d[Mn_Mo_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$Mn_{Bi1}-Mo_{Bi2}$', color=col)

plt.ylabel('$|\mathbf{D}_{ij}|$ (meV)', fontsize='x-large')
plt.xlabel('$R_{ij}$ ($\AA$)', fontsize='x-large')
plt.ylim(ylim_abs_D)
plt.xlim(xlim)
plt.legend(fontsize=legend_fontsize, loc=1, prop = legnd_prop)
plt.axhline(0.0, ls='--', color='gray', alpha=0.4)

plt.subplot(4,3,9)
#plt.title('D/J', fontsize='x-large')
mask = np.where(r<=mask_limit)

col = 'r'
rr, dd, jj = r[mask], d[mask], Mn_Mn_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color=col)
plt.plot(rr[jj[:,1]==10], abs(dd/jj[:,5])[jj[:,1]==10], '*', ms=10, color=col, label='$Mn_{Bi1}-Mn_{Bi1}$')
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$Mn_{Bi1}-Mn_{Bi2}$')

col ='g'
rr, dd, jj = r[mask], d[mask], Mn_Cr_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color='g')
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$Mn_{Bi1}-Cr_{Bi2}$')

col = 'b'
rr, dd, jj = r[mask], d[mask], Mn_V_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color=col)
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$Mn_{Bi1}-V_{Bi2}$')

col = 'c'
rr, dd, jj = r[mask], d[mask], Mn_Mo_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color=col)
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$Mn_{Bi1}-Mo_{Bi2}$')


plt.ylabel('$|\mathbf{D}_{ij}|J_{ij}$', fontsize='x-large')
plt.xlabel('$R_{ij}$ ($\AA$)', fontsize='x-large')
plt.ylim(ylim_ratio)
plt.xlim(xlim)

plt.legend(fontsize=legend_fontsize, loc=1, prop = legnd_prop)
plt.twinx()
#plt.plot(r[mask], (V_V_pos[:,2])[mask], 's:', color='grey')
plt.axhline(0, ls=':', color='grey')
plt.ylabel('z distance ($\AA$)')

## Plot Mo ++++++++++++++++++++# Mo#---------------------------------------------------
#mp.rcParams['text.usetex'] = True

# plt.subplot(2,1,1)
plt.subplot(4,3,10)
#plt.title('Mo-(V,Cr,Mn,Mo) Exchange interaction vs. distance', fontsize='x-large')

#r0 = np.sqrt(np.sum(pos0**2, axis=1))
#plt.plot(r0, jijs0[:,5], 'kd', ms=15, label='smaller k-mesh')

col = 'r'
r = np.sqrt(np.sum(Mo_Mo_pos**2, axis=1))
plt.plot(r, Mo_Mo_jijs[:,5], ':', color='r')
plt.plot(r[Mo_Mo_jijs[:,1]==10], Mo_Mo_jijs[Mo_Mo_jijs[:,1]==10][:,5], '*', ms=10, alpha=0.5, label='$Mo_{Bi1}-Mo_{Bi1}$', color=col)
plt.plot(r[Mo_Mo_jijs[:,1]==12], Mo_Mo_jijs[Mo_Mo_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$Mo_{Bi1}-Mo_{Bi2}$', color=col)

col ='g'
r = np.sqrt(np.sum(Mo_Cr_pos**2, axis=1))
plt.plot(r, Mo_Cr_jijs[:,5], ':', color='g')
plt.plot(r[Mo_Cr_jijs[:,1]==12], Mo_Cr_jijs[Mo_Cr_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$Mo_{Bi1}-Cr_{Bi2}$', color=col)

col = 'b'
r = np.sqrt(np.sum(Mo_V_pos**2, axis=1))
plt.plot(r, Mo_V_jijs[:,5], ':', color='b')
plt.plot(r[Mo_V_jijs[:,1]==12], Mo_V_jijs[Mo_V_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$Mo_{Bi1}-V_{Bi2}$', color=col)

col = 'c'
r = np.sqrt(np.sum(Mo_Mn_pos**2, axis=1))
plt.plot(r, Mo_Mn_jijs[:,5], ':', color='c')
plt.plot(r[Mo_Mn_jijs[:,1]==12], Mo_Mn_jijs[Mo_Mn_jijs[:,1]==12][:,5], 's', ms=9, alpha=0.5, label='$Mo_{Bi1}-Mn_{Bi2}$', color=col)

plt.ylabel('$J_{ij}$ (meV)', fontsize='x-large')
plt.axhline(0, ls='--', color='grey')
plt.xlabel('$R_{ij}$ ($\AA$)', fontsize='x-large')
plt.xlim(xlim)
plt.ylim(ylim_J)
plt.legend(fontsize=legend_fontsize, loc=1, prop = legnd_prop)


plt.subplot(4,3,11)
#plt.title('DMI vs. distance', fontsize='x-large')

col = 'r'
d = np.sqrt(np.sum(Mo_Mo_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='r')
plt.plot(r[Mo_Mo_jijs[:,1]==10], d[Mo_Mo_jijs[:,1]==10], '*', ms=10, alpha=0.5, label='$Mo_{Bi1}-Mo_{Bi1}$', color=col)
plt.plot(r[Mo_Mo_jijs[:,1]==12], d[Mo_Mo_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$Mo_{Bi1}-Mo_{Bi2}$', color=col)

col ='g'
d = np.sqrt(np.sum(Mo_Cr_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='g')
plt.plot(r[Mo_Cr_jijs[:,1]==12], d[Mo_Cr_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$Mo_{Bi1}-Cr_{Bi2}$', color=col)

col = 'b'
d = np.sqrt(np.sum(Mo_Mn_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='b')
plt.plot(r[Mo_Mn_jijs[:,1]==12], d[Mo_Mn_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$Mo_{Bi1}-Mn_{Bi2}$', color=col)

col = 'c'
d = np.sqrt(np.sum(Mo_V_jijs[:,6:9]**2, axis=1))
plt.plot(r,d, ':', color='c')
plt.plot(r[Mo_V_jijs[:,1]==12], d[Mo_V_jijs[:,1]==12], 's', ms=9, alpha=0.5, label='$Mo_{Bi1}-V_{Bi2}$', color=col)

plt.ylabel('$|\mathbf{D}_{ij}|$ (meV)', fontsize='x-large')
plt.xlabel('$R_{ij}$ ($\AA$)', fontsize='x-large')
plt.ylim(ylim_abs_D)
plt.xlim(xlim)
plt.legend(fontsize=legend_fontsize, loc=1, prop = legnd_prop)
plt.axhline(0.0, ls='--', color='gray', alpha=0.4)


plt.subplot(4,3,12)
#plt.title('D/J', fontsize='x-large')
mask = np.where(r<=mask_limit)

col = 'r'
rr, dd, jj = r[mask], d[mask], Mo_Mo_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color=col)
plt.plot(rr[jj[:,1]==10], abs(dd/jj[:,5])[jj[:,1]==10], '*', ms=10, color=col, label='$Mo_{Bi1}-Mo_{Bi1}$')
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$Mo_{Bi1}-Mo_{Bi2}$')

col ='g'
rr, dd, jj = r[mask], d[mask], Mo_Cr_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color='g')
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$Mo_{Bi1}-Cr_{Bi2}$')

col = 'b'
rr, dd, jj = r[mask], d[mask], Mo_Mn_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color=col)
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$Mo_{Bi1}-Mn_{Bi2}$')

col = 'c'
rr, dd, jj = r[mask], d[mask], Mo_V_jijs[mask]
plt.plot(rr, abs(dd/jj[:,5]), ':', color=col)
plt.plot(rr[jj[:,1]==12], abs(dd/jj[:,5])[jj[:,1]==12], 's', ms=9, color=col, label='$Mo_{Bi1}-V_{Bi2}$')

plt.ylabel('$|\mathbf{D}_{ij}|/J_{ij}$', fontsize='x-large')
plt.xlabel('$R_{ij}$ ($\AA$)', fontsize='x-large')
#plt.twiny
plt.ylim(ylim_ratio)
plt.xlim(xlim)

plt.legend(fontsize=legend_fontsize, loc=1, prop = legnd_prop)
#plt.plot(r[mask], (V_V_pos[:,2])[mask], 's:', color='grey')
plt.axhline(0, ls=':', color='grey')
plt.twinx()
plt.ylabel('z distance ($\AA$)')

plt.tight_layout()

plt.show()
